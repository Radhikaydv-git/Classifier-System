# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhikaydv-git/Classifier-System/blob/main/Handwritten_Digit_Recognition_using_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_digits

# %%
dataset=load_digits()

# %%
print(dataset.data)
print(dataset.target)
print(dataset.data.shape)
print(dataset.images.shape)
dataimageLength = len(dataset.images)
print(dataimageLength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %%
n=1
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(dataset.images[n])
plt.show()
dataset.images[n]

# %%
X = dataset.images.reshape((dataimageLength,-1))
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
Y = dataset.target
print(Y)
# Out:
# [0 1 2 ... 8 9 8]

# %%
X = dataset.images.reshape((dataimageLength,-1))
print(X)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test,y_train,y_test = train_test_split(X,Y, test_size = 0.25,random_state =0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %%
from sklearn import svm
model   = svm.SVC(kernel = 'linear')
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
n = 1
result = model.predict(dataset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n],cmap = plt.cm.gray_r,interpolation = 'nearest')
print(result)
print("\n")
plt.axis('off')
plt.title('%i'%result)
plt.show()
# Out:
# [1]

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [4 7]
#  [3 3]
# ...

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the Model :- {0}%".format(accuracy_score(y_test,y_pred)*100))
# Out:
# Accuracy of the Model :- 97.11111111111111%

# %%
from sklearn import svm
model1 = svm.SVC(kernel = 'linear')
model2 = svm.SVC(kernel = 'rbf')
model3 = svm.SVC(gamma = 0.001)
model4 = svm.SVC(gamma = 0.001, C =0.1)

model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
model4.fit(X_train,y_train)

y_predModel1 = model1.predict(X_test)
y_predModel2 = model2.predict(X_test)
y_predModel3 = model3.predict(X_test)
y_predModel4 = model4.predict(X_test)

print("Accuracy of the Model 1 :- {0}%".format(accuracy_score(y_test,y_predModel1)*100))
print("Accuracy of the Model 2 :- {0}%".format(accuracy_score(y_test,y_predModel2)*100))
print("Accuracy of the Model 3 :- {0}%".format(accuracy_score(y_test,y_predModel3)*100))
print("Accuracy of the Model 4 :- {0}%".format(accuracy_score(y_test,y_predModel4)*100))
# Out:
# Accuracy of the Model 1 :- 97.11111111111111%
# Accuracy of the Model 2 :- 99.11111111111111%
# Accuracy of the Model 3 :- 99.55555555555556%
# Accuracy of the Model 4 :- 96.66666666666667%

# %% [markdown]
# # Digit Recognition Project
#
# This project implements a digit recognition model using the scikit-learn library in Google Colab. It utilizes the `load_digits` dataset to train and evaluate different Support Vector Machine (SVM) models.
#
# ## Project Description
#
# The goal of this project is to build a model that can accurately identify handwritten digits. The process involves loading the dataset, splitting it into training and testing sets, training various SVM models with different kernels and parameters, and evaluating their accuracy.
#
# ## Technologies Used
#
# *   Python
# *   Google Colab
# *   NumPy
# *   Scikit-learn
# *   Matplotlib
#
# ## Setup and Installation
#
# This project can be run directly in Google Colab. No local installation is required other than having a Google account to access Colab.
#
# 1.  Open the notebook in Google Colab.
# 2.  Run the cells sequentially to load the data, preprocess it, train the models, and evaluate their performance.
#
# ## How to Run
#
# Simply open the `.ipynb` notebook file in Google Colab and run all the cells. The output will show the accuracy of different SVM models trained on the digit dataset.
#
# ## Results
#
# The notebook trains and evaluates multiple SVM models with different kernels and parameters. The accuracies of these models are printed in the output cells. The model with `gamma=0.001` achieved the highest accuracy.
#
# ## Files
#
# *   `your_notebook_name.ipynb`: The main Google Colab notebook containing the code for this project. (Remember to replace `your_notebook_name.ipynb` with the actual name of your notebook file).
#
# ## Future Improvements
#
# *   Experiment with other classification algorithms (e.g., K-Nearest Neighbors, Neural Networks).
# *   Perform hyperparameter tuning to further optimize the model performance.
# *   Implement cross-validation for more robust model evaluation.
# *   Visualize misclassified digits to understand model errors.
#
# ## License
#
# This project is licensed under the [Choose a license, e.g., MIT License](LICENSE) - see the LICENSE file for details. (You'll need to add a LICENSE file to your repository if you choose a license).
